# %%
import pandas as pd 
import numpy as np
import pycountry

# %%
#this is the worst part of the whole code
kw_dict = {'Arts and culture': 'NA', 'Sport': 'NA', 'Television': 'NA', 'Games': 'NA', 'Science and technology': 'NA', 'Health': 'NA', 'Health and environment': 'NA', ' Ernest Smith being moved into the church.': 'NA', ' River Thames whale': 'NA', ' Samuel Alito': 'NA', 'Discoveries': 'NA', 'Environment': 'NA', 'Weather': 'NA', 'Science': 'NA', 'Sports': 'NA', 'Arts and entertainment': 'NA', 'Arts, culture and entertainment': 'NA', 'Law and Crime': 'NA', 'Arts and Culture': 'NA', 'Entertainment': 'NA', 'Law and crimes': 'NA', 'Science ': 'NA', 'Art and culture': 'NA', 'Sport ': 'NA', 'Science and environment': 'NA', 'Arts, culture': 'NA', 'Law and crime ': 'NA', 'Technology': 'NA', 'Home Video': 'NA', 'Arts & Culture': 'NA', 'Arts and culture ': 'NA', 'Bird Deaths': 'NA', 'Science and medicine': 'NA', 'Transport': 'NA', 'Health and wellness': 'NA', 'Culture': 'NA', 'History': 'NA', ' Transport\xa0:': 'NA', 'Sports ': 'NA', ' Arts and culture': 'NA', ' Science': 'NA', ' Sport': 'NA', ' Environment': 'NA', 'Natural history': 'NA', 'Transportation': 'NA', 'Movies': 'NA', 'Intragalactic relations': 'NA', 'Other': 'NA', 'Geography': 'NA', 'Sports and Recreation': 'NA', 'Science and health': 'NA', 'Education': 'NA', 'Science, medicine and technology': 'NA', 'Environment and health': 'NA', 'Video Games': 'NA', 'Religion and spirituality': 'NA', 'Media and people': 'NA', 'Deaths': 'NA', 'Life and death': 'NA', 'Society': 'NA', 'Literature': 'NA', 'Science and technology ': 'NA', 'Science and Technology': 'NA', 'Innovation and technology': 'NA', 'Love': 'NA', 'Exploration': 'NA', 'Media': 'NA', 'Physics': 'NA', 'Medicine': 'NA', 'Films': 'NA', ' Science and technology': 'NA', 'Business Environmental': 'NA', 'Technology and science': 'NA', 'Health and medicine': 'NA', 'Gaming': 'NA', 'Business and Video games': 'NA', 'Music': 'NA', 'Health and science': 'NA', 'Health ': 'NA', 'Arts and cuture': 'NA', 'Miscellaneous news': 'NA', 'Health and Medicine': 'NA', ' Health and medicine': 'NA', 'Law and crime:': 'NA', 'Sports:': 'NA', 'Art & literature': 'NA', 'Science and nature': 'NA', 'Health and medicine ': 'NA', 'Culture and media': 'NA', 'Arts and cultures': 'NA', 'Health and environment ': 'NA', 'Arts and culture;': 'NA', 'Video games': 'NA', 'Science and research': 'NA', 'Art and culture ': 'NA', 'Business and economy': 'econ', 'Business and economics': 'econ', 'Business and Economy': 'econ', 'Business': 'econ', 'Business and economy ': 'econ', 'Business and Economics': 'econ', 'Business and economy   ': 'econ', ' Business and economics': 'econ', 'Business and finance': 'econ', 'Economics': 'econ', 'Economics and business': 'econ', 'Business and economies': 'econ', ' Business and economy': 'econ', 'Finance': 'econ', 'Business and Finance': 'econ', 'Economy and finance': 'econ', 'Business and economic': 'econ', 'Businesses and economy': 'econ', 'Business and the economy': 'econ', 'Business and economy:': 'econ', 'Business and economics ': 'econ', 'Business  and  economy': 'econ', 'International relations': 'IR', 'International Relations': 'IR', 'International relations:': 'IR', ' International relations': 'IR', 'International relations ': 'IR', 'International Relations ': 'IR', 'International relations  ': 'IR', 'International relation': 'IR', 'Armed conflicts and attacks': 'conflict', 'Armed conflicts and incidents': 'conflict', 'Armed conflict and incidents': 'conflict', 'Armed conflicts': 'conflict', 'Armed conflicts and attacks ': 'conflict', 'Armed conflicts ': 'conflict', 'Armed conflict and attacks': 'conflict', ' Armed conflicts and attacks': 'conflict', ' Armed conflict and attacks': 'conflict', 'Armed conflict': 'conflict', 'Conflicts': 'conflict', 'Armed attacks and conflicts': 'conflict', 'Armed attacks': 'conflict', 'Armed conflict and attacks ': 'conflict', 'Attacks and conflicts': 'conflict', 'Armed conflict and attack': 'conflict', 'Armed Conflicts and attacks': 'conflict', 'Conflicts and attacks ': 'conflict', 'Attacks and armed conflicts': 'conflict', 'Armed conflicts and attack': 'conflict', 'Conflicts and attacks': 'conflict', 'Armed conflicts and attacks:': 'conflict', 'Armed conflicts and attacks   ': 'conflict', 'Law and crime': 'politics', 'Laws and crimes': 'politics', 'Law': 'politics', 'Crimes': 'politics', 'Politics and elections': 'politics', 'Politics': 'politics', 'Politics ': 'politics', 'Politics and government': 'politics', 'Arab Spring': 'politics', ' Law and crime': 'politics', ' Politics and elections': 'politics', 'Law and Order': 'politics', 'Politics and elections ': 'politics', 'Arrests, detentions and prosecutions': 'politics', 'Legal and crime': 'politics', 'Law enforcement and crime': 'politics', 'Politics and protests': 'politics', 'Politics and elections:': 'politics', 'Politics and election': 'politics', 'Religious affairs': 'politics', 'Human rights': 'politics', 'Religion and diplomacy': 'politics', 'Politics and Elections': 'politics', ' Religion': 'politics', 'Law and justice': 'politics', 'Law & crime': 'politics', 'Laws and crime': 'politics', ' Defence': 'politics', 'Politics & Elections': 'politics', 'Law, crime and accidents': 'politics', 'Law and order': 'politics', 'Elections and politics': 'politics', 'Political elections': 'politics', 'Crime': 'politics', 'Crime and law': 'politics', 'Religion': 'politics', 'A sandstorm in Iraq on April 27, 2005': 'disaster', 'Disasters and accidents': 'disaster', 'Disasters': 'disaster', 'Disasters ': 'disaster', ' Disasters': 'disaster', 'Disaster ': 'disaster', 'Disaster': 'disaster', 'Emergency Alerts': 'disaster', 'Accidents and disasters': 'disaster', 'Disaster and accidents': 'disaster', 'Disasters and accidents ': 'disaster', 'Disasters and accidents,': 'disaster', ' Disasters and accidents': 'disaster', 'Natural disasters': 'disaster', 'Disasters and impacts': 'disaster', 'Disasters and Accidents': 'disaster', 'Accidents': 'disaster', 'Accidents and Disasters': 'disaster', 'Disasters and accident': 'disaster', 'Disasters and incidents': 'disaster', 'Disasters and accidents  ': 'disaster'}
country_map = {'Afghanistan': 'AFG', 'Åland Islands': 'ALA', 'Albania': 'ALB', 'Algeria': 'DZA', 'American Samoa': 'ASM', 'Andorra': 'AND', 'Angola': 'AGO', 'Anguilla': 'AIA', 'Antarctica': 'ATA', 'Antigua and Barbuda': 'ATG', 'Argentina': 'ARG', 'Armenia': 'ARM', 'Aruba': 'ABW', 'Australia': 'AUS', 'Austria': 'AUT', 'Azerbaijan': 'AZE', 'Bahamas': 'BHS', 'Bahrain': 'BHR', 'Bangladesh': 'BGD', 'Barbados': 'BRB', 'Belarus': 'BLR', 'Belgium': 'BEL', 'Belize': 'BLZ', 'Benin': 'BEN', 'Bermuda': 'BMU', 'Bhutan': 'BTN', 'Bolivia (Plurinational State of)': 'BOL', 'Bonaire, Sint Eustatius and Saba': 'BES', 'Bosnia and Herzegovina': 'BIH', 'Botswana': 'BWA', 'Bouvet Island': 'BVT', 'Brazil': 'BRA', 'British Indian Ocean Territory': 'IOT', 'Brunei Darussalam': 'BRN', 'Bulgaria': 'BGR', 'Burkina Faso': 'BFA', 'Burundi': 'BDI', 'Cabo Verde': 'CPV', 'Cambodia': 'KHM', 'Cameroon': 'CMR', 'Canada': 'CAN', 'Cayman Islands': 'CYM', 'Central African Republic': 'CAF', 'Chad': 'TCD', 'Chile': 'CHL', 'China': 'CHN', 'Christmas Island': 'CXR', 'Cocos (Keeling) Islands': 'CCK', 'Colombia': 'COL', 'Comoros': 'COM', 'Congo': 'COG', 'Congo, Democratic Republic of the': 'COD', 'Cook Islands': 'COK', 'Costa Rica': 'CRI', "Côte d'Ivoire": 'CIV', 'Croatia': 'HRV', 'Cuba': 'CUB', 'Curaçao': 'CUW', 'Cyprus': 'CYP', 'Czechia': 'CZE', 'Denmark': 'DNK', 'Djibouti': 'DJI', 'Dominica': 'DMA', 'Dominican Republic': 'DOM', 'Ecuador': 'ECU', 'Egypt': 'EGY', 'El Salvador': 'SLV', 'Equatorial Guinea': 'GNQ', 'Eritrea': 'ERI', 'Estonia': 'EST', 'Eswatini': 'SWZ', 'Ethiopia': 'ETH', 'Falkland Islands (Malvinas)': 'FLK', 'Faroe Islands': 'FRO', 'Fiji': 'FJI', 'Finland': 'FIN', 'France': 'FRA', 'French Guiana': 'GUF', 'French Polynesia': 'PYF', 'French Southern Territories': 'ATF', 'Gabon': 'GAB', 'Gambia': 'GMB', 'Georgia': 'GEO', 'Germany': 'DEU', 'Ghana': 'GHA', 'Gibraltar': 'GIB', 'Greece': 'GRC', 'Greenland': 'GRL', 'Grenada': 'GRD', 'Guadeloupe': 'GLP', 'Guam': 'GUM', 'Guatemala': 'GTM', 'Guernsey': 'GGY', 'Guinea': 'GIN', 'Guinea-Bissau': 'GNB', 'Guyana': 'GUY', 'Haiti': 'HTI', 'Heard Island and McDonald Islands': 'HMD', 'Holy See': 'VAT', 'Honduras': 'HND', 'Hong Kong': 'HKG', 'Hungary': 'HUN', 'Iceland': 'ISL', 'India': 'IND', 'Indonesia': 'IDN', 'Iran (Islamic Republic of)': 'IRN', 'Iraq': 'IRQ', 'Ireland': 'IRL', 'Isle of Man': 'IMN', 'Israel': 'ISR', 'Italy': 'ITA','Jamaica': 'JAM', 'Japan': 'JPN', 'Jersey': 'JEY', 'Jordan': 'JOR', 'Kazakhstan': 'KAZ', 'Kenya': 'KEN', 'Kiribati': 'KIR', "Korea (Democratic People's Republic of)": 'PRK', 'Korea, Republic of': 'KOR', 'Kuwait': 'KWT', 'Kyrgyzstan': 'KGZ', "Lao People's Democratic Republic": 'LAO', 'Latvia': 'LVA', 'Lebanon': 'LBN', 'Lesotho': 'LSO', 'Liberia': 'LBR', 'Libya': 'LBY', 'Liechtenstein': 'LIE', 'Lithuania': 'LTU', 'Luxembourg': 'LUX', 'Macao': 'MAC', 'Madagascar': 'MDG', 'Malawi': 'MWI', 'Malaysia': 'MYS', 'Maldives': 'MDV', 'Mali': 'MLI', 'Malta': 'MLT', 'Marshall Islands': 'MHL', 'Martinique': 'MTQ', 'Mauritania': 'MRT', 'Mauritius': 'MUS', 'Mayotte': 'MYT', 'Mexico': 'MEX', 'Micronesia (Federated States of)': 'FSM', 'Moldova, Republic of': 'MDA', 'Monaco': 'MCO', 'Mongolia': 'MNG', 'Montenegro': 'MNE', 'Montserrat': 'MSR', 'Morocco': 'MAR', 'Mozambique': 'MOZ', 'Myanmar': 'MMR', 'Namibia': 'NAM', 'Nauru': 'NRU', 'Nepal': 'NPL', 'Netherlands': 'NLD', 'New Caledonia': 'NCL', 'New Zealand': 'NZL', 'Nicaragua': 'NIC', 'Niger': 'NER', 'Nigeria': 'NGA', 'Niue': 'NIU', 'Norfolk Island': 'NFK', 'North Macedonia': 'MKD', 'Northern Mariana Islands': 'MNP', 'Norway': 'NOR', 'Oman': 'OMN', 'Pakistan': 'PAK', 'Palau': 'PLW', 'Palestine, State of': 'PSE', 'Panama': 'PAN', 'Papua New Guinea': 'PNG', 'Paraguay': 'PRY', 'Peru': 'PER', 'Philippines': 'PHL', 'Pitcairn': 'PCN', 'Poland': 'POL', 'Portugal': 'PRT', 'Puerto Rico': 'PRI', 'Qatar': 'QAT', 'Réunion': 'REU', 'Romania': 'ROU', 'Russian Federation': 'RUS', 'Rwanda': 'RWA', 'Saint Barthélemy': 'BLM', 'Saint Helena, Ascension and Tristan da Cunha': 'SHN', 'Saint Kitts and Nevis': 'KNA', 'Saint Lucia': 'LCA', 'Saint Martin (French part)': 'MAF', 'Saint Pierre and Miquelon': 'SPM', 'Saint Vincent and the Grenadines': 'VCT', 'Samoa': 'WSM', 'San Marino': 'SMR', 'Sao Tome and Principe': 'STP', 'Saudi Arabia': 'SAU', 'Senegal': 'SEN', 'Serbia': 'SRB', 'Seychelles': 'SYC', 'Sierra Leone': 'SLE', 'Singapore': 'SGP', 'Sint Maarten (Dutch part)': 'SXM', 'Slovakia': 'SVK', 'Slovenia': 'SVN', 'Solomon Islands': 'SLB', 'Somalia': 'SOM', 'South Africa': 'ZAF', 'South Georgia and the South Sandwich Islands': 'SGS', 'South Sudan': 'SSD', 'Spain': 'ESP', 'Sri Lanka': 'LKA', 'Sudan': 'SDN', 'Suriname': 'SUR', 'Svalbard and Jan Mayen': 'SJM', 'Sweden': 'SWE', 'Switzerland': 'CHE', 'Syrian Arab Republic': 'SYR', 'Taiwan, Province of China': 'TWN', 'Tajikistan': 'TJK', 'Tanzania, United Republic of': 'TZA', 'Thailand': 'THA', 'Timor-Leste': 'TLS', 'Togo': 'TGO', 'Tokelau': 'TKL', 'Tonga': 'TON', 'Trinidad and Tobago': 'TTO', 'Tunisia': 'TUN', 'Turkey': 'TUR', 'Turkmenistan': 'TKM', 'Turks and Caicos Islands': 'TCA', 'Tuvalu': 'TUV', 'Uganda': 'UGA', 'Ukraine': 'UKR', 'United Arab Emirates': 'ARE', 'United Kingdom': 'GBR', 'United States': 'USA', 'United States Minor Outlying Islands': 'UMI', 'Uruguay': 'URY', 'Uzbekistan': 'UZB', 'Vanuatu': 'VUT', 'Venezuela (Bolivarian Republic of)': 'VEN', 'Viet Nam': 'VNM', 'Virgin Islands (British)': 'VGB', 'Virgin Islands (U.S.)': 'VIR', 'Wallis and Futuna': 'WLF', 'Western Sahara': 'ESH', 'Yemen': 'YEM', 'Zambia': 'ZMB', 'Zimbabwe': 'ZWE'}
# Source: https://raw.githubusercontent.com/lukes/ISO-3166-Countries-with-Regional-Codes/master/all/all.csv 
# Source Kw_dict: mapped unique values of category by hand

#read in the full panel
df = pd.read_csv("temp/total_events_full.csv")
#Dropping covid events - as it was usually case counts etc.
df = df[df["descr"].str.contains("covid")==False]
df = df.drop_duplicates(keep='last')

print(df.shape)

#remap the category by user defined key
df["cat"] = df["cat"].map(kw_dict)
df = df[df["cat"].str.contains("NA")==False]

df.to_csv('data/cleaned_full.csv')

#loop over each event, extract countries involved, and make dummy variables
for index, row in df.iterrows():
    text = row['descr']
    cat_out = row['cat']
    
    #make dummy variable for that day, if country is detected
    for country in pycountry.countries:
        if country.name in text:
            country_code = country.name
            #map to ISO-3 codes
            for word, replacement in country_map.items():
                country_code = country_code.replace(word, replacement)
            if len(country_code) != 3:
                continue
            df.loc[index,f"{country_code}_{cat_out}"] = 1


#should probably be around 1000 cols wide??
print(df.shape)
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d %H:%M:%S')
df = df.set_index('date')
agg = df.resample('D').sum()

agg.to_csv('data/cleaned.csv')
# Out:
# (47063, 4)
# /var/folders/3_/4hp02k9s28l0xngsnvfp3jl40000gn/T/ipykernel_41091/2971795096.py:35: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f"{country_code}_{cat_out}"] = 1
# /var/folders/3_/4hp02k9s28l0xngsnvfp3jl40000gn/T/ipykernel_41091/2971795096.py:35: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f"{country_code}_{cat_out}"] = 1
# ...

# %%
#random code pieces that were used to setup the mapping and stuff

countries = df.c1.unique()
df_country_list = pd.DataFrame(countries, columns = ['countries'])
df_country_list.to_csv('temp/country_list.csv')
df_country_list = pd.read_csv('temp/country_list.csv')
country_map = {'Afghanistan': 'AFG', 'Åland Islands': 'ALA', 'Albania': 'ALB', 'Algeria': 'DZA', 'American Samoa': 'ASM', 'Andorra': 'AND', 'Angola': 'AGO', 'Anguilla': 'AIA', 'Antarctica': 'ATA', 'Antigua and Barbuda': 'ATG', 'Argentina': 'ARG', 'Armenia': 'ARM', 'Aruba': 'ABW', 'Australia': 'AUS', 'Austria': 'AUT', 'Azerbaijan': 'AZE', 'Bahamas': 'BHS', 'Bahrain': 'BHR', 'Bangladesh': 'BGD', 'Barbados': 'BRB', 'Belarus': 'BLR', 'Belgium': 'BEL', 'Belize': 'BLZ', 'Benin': 'BEN', 'Bermuda': 'BMU', 'Bhutan': 'BTN', 'Bolivia (Plurinational State of)': 'BOL', 'Bonaire, Sint Eustatius and Saba': 'BES', 'Bosnia and Herzegovina': 'BIH', 'Botswana': 'BWA', 'Bouvet Island': 'BVT', 'Brazil': 'BRA', 'British Indian Ocean Territory': 'IOT', 'Brunei Darussalam': 'BRN', 'Bulgaria': 'BGR', 'Burkina Faso': 'BFA', 'Burundi': 'BDI', 'Cabo Verde': 'CPV', 'Cambodia': 'KHM', 'Cameroon': 'CMR', 'Canada': 'CAN', 'Cayman Islands': 'CYM', 'Central African Republic': 'CAF', 'Chad': 'TCD', 'Chile': 'CHL', 'China': 'CHN', 'Christmas Island': 'CXR', 'Cocos (Keeling) Islands': 'CCK', 'Colombia': 'COL', 'Comoros': 'COM', 'Congo': 'COG', 'Congo, Democratic Republic of the': 'COD', 'Cook Islands': 'COK', 'Costa Rica': 'CRI', "Côte d'Ivoire": 'CIV', 'Croatia': 'HRV', 'Cuba': 'CUB', 'Curaçao': 'CUW', 'Cyprus': 'CYP', 'Czechia': 'CZE', 'Denmark': 'DNK', 'Djibouti': 'DJI', 'Dominica': 'DMA', 'Dominican Republic': 'DOM', 'Ecuador': 'ECU', 'Egypt': 'EGY', 'El Salvador': 'SLV', 'Equatorial Guinea': 'GNQ', 'Eritrea': 'ERI', 'Estonia': 'EST', 'Eswatini': 'SWZ', 'Ethiopia': 'ETH', 'Falkland Islands (Malvinas)': 'FLK', 'Faroe Islands': 'FRO', 'Fiji': 'FJI', 'Finland': 'FIN', 'France': 'FRA', 'French Guiana': 'GUF', 'French Polynesia': 'PYF', 'French Southern Territories': 'ATF', 'Gabon': 'GAB', 'Gambia': 'GMB', 'Georgia': 'GEO', 'Germany': 'DEU', 'Ghana': 'GHA', 'Gibraltar': 'GIB', 'Greece': 'GRC', 'Greenland': 'GRL', 'Grenada': 'GRD', 'Guadeloupe': 'GLP', 'Guam': 'GUM', 'Guatemala': 'GTM', 'Guernsey': 'GGY', 'Guinea': 'GIN', 'Guinea-Bissau': 'GNB', 'Guyana': 'GUY', 'Haiti': 'HTI', 'Heard Island and McDonald Islands': 'HMD', 'Holy See': 'VAT', 'Honduras': 'HND', 'Hong Kong': 'HKG', 'Hungary': 'HUN', 'Iceland': 'ISL', 'India': 'IND', 'Indonesia': 'IDN', 'Iran (Islamic Republic of)': 'IRN', 'Iraq': 'IRQ', 'Ireland': 'IRL', 'Isle of Man': 'IMN', 'Israel': 'ISR', 'Italy': 'ITA','Jamaica': 'JAM', 'Japan': 'JPN', 'Jersey': 'JEY', 'Jordan': 'JOR', 'Kazakhstan': 'KAZ', 'Kenya': 'KEN', 'Kiribati': 'KIR', "Korea (Democratic People's Republic of)": 'PRK', 'Korea, Republic of': 'KOR', 'Kuwait': 'KWT', 'Kyrgyzstan': 'KGZ', "Lao People's Democratic Republic": 'LAO', 'Latvia': 'LVA', 'Lebanon': 'LBN', 'Lesotho': 'LSO', 'Liberia': 'LBR', 'Libya': 'LBY', 'Liechtenstein': 'LIE', 'Lithuania': 'LTU', 'Luxembourg': 'LUX', 'Macao': 'MAC', 'Madagascar': 'MDG', 'Malawi': 'MWI', 'Malaysia': 'MYS', 'Maldives': 'MDV', 'Mali': 'MLI', 'Malta': 'MLT', 'Marshall Islands': 'MHL', 'Martinique': 'MTQ', 'Mauritania': 'MRT', 'Mauritius': 'MUS', 'Mayotte': 'MYT', 'Mexico': 'MEX', 'Micronesia (Federated States of)': 'FSM', 'Moldova, Republic of': 'MDA', 'Monaco': 'MCO', 'Mongolia': 'MNG', 'Montenegro': 'MNE', 'Montserrat': 'MSR', 'Morocco': 'MAR', 'Mozambique': 'MOZ', 'Myanmar': 'MMR', 'Namibia': 'NAM', 'Nauru': 'NRU', 'Nepal': 'NPL', 'Netherlands': 'NLD', 'New Caledonia': 'NCL', 'New Zealand': 'NZL', 'Nicaragua': 'NIC', 'Niger': 'NER', 'Nigeria': 'NGA', 'Niue': 'NIU', 'Norfolk Island': 'NFK', 'North Macedonia': 'MKD', 'Northern Mariana Islands': 'MNP', 'Norway': 'NOR', 'Oman': 'OMN', 'Pakistan': 'PAK', 'Palau': 'PLW', 'Palestine, State of': 'PSE', 'Panama': 'PAN', 'Papua New Guinea': 'PNG', 'Paraguay': 'PRY', 'Peru': 'PER', 'Philippines': 'PHL', 'Pitcairn': 'PCN', 'Poland': 'POL', 'Portugal': 'PRT', 'Puerto Rico': 'PRI', 'Qatar': 'QAT', 'Réunion': 'REU', 'Romania': 'ROU', 'Russian Federation': 'RUS', 'Rwanda': 'RWA', 'Saint Barthélemy': 'BLM', 'Saint Helena, Ascension and Tristan da Cunha': 'SHN', 'Saint Kitts and Nevis': 'KNA', 'Saint Lucia': 'LCA', 'Saint Martin (French part)': 'MAF', 'Saint Pierre and Miquelon': 'SPM', 'Saint Vincent and the Grenadines': 'VCT', 'Samoa': 'WSM', 'San Marino': 'SMR', 'Sao Tome and Principe': 'STP', 'Saudi Arabia': 'SAU', 'Senegal': 'SEN', 'Serbia': 'SRB', 'Seychelles': 'SYC', 'Sierra Leone': 'SLE', 'Singapore': 'SGP', 'Sint Maarten (Dutch part)': 'SXM', 'Slovakia': 'SVK', 'Slovenia': 'SVN', 'Solomon Islands': 'SLB', 'Somalia': 'SOM', 'South Africa': 'ZAF', 'South Georgia and the South Sandwich Islands': 'SGS', 'South Sudan': 'SSD', 'Spain': 'ESP', 'Sri Lanka': 'LKA', 'Sudan': 'SDN', 'Suriname': 'SUR', 'Svalbard and Jan Mayen': 'SJM', 'Sweden': 'SWE', 'Switzerland': 'CHE', 'Syrian Arab Republic': 'SYR', 'Taiwan, Province of China': 'TWN', 'Tajikistan': 'TJK', 'Tanzania, United Republic of': 'TZA', 'Thailand': 'THA', 'Timor-Leste': 'TLS', 'Togo': 'TGO', 'Tokelau': 'TKL', 'Tonga': 'TON', 'Trinidad and Tobago': 'TTO', 'Tunisia': 'TUN', 'Turkey': 'TUR', 'Turkmenistan': 'TKM', 'Turks and Caicos Islands': 'TCA', 'Tuvalu': 'TUV', 'Uganda': 'UGA', 'Ukraine': 'UKR', 'United Arab Emirates': 'ARE', 'United Kingdom': 'GBR', 'United States': 'USA', 'United States Minor Outlying Islands': 'UMI', 'Uruguay': 'URY', 'Uzbekistan': 'UZB', 'Vanuatu': 'VUT', 'Venezuela (Bolivarian Republic of)': 'VEN', 'Viet Nam': 'VNM', 'Virgin Islands (British)': 'VGB', 'Virgin Islands (U.S.)': 'VIR', 'Wallis and Futuna': 'WLF', 'Western Sahara': 'ESH', 'Yemen': 'YEM', 'Zambia': 'ZMB', 'Zimbabwe': 'ZWE'}
df_new = df_country_list.replace({"countries": country_map})
df_new.to_csv('temp/map_match.csv')

cats = df.cat.unique()
df_cat_list = pd.DataFrame(cats, columns = ['category'])
df_cat_list.to_csv('extras/category.csv')
kw_map = pd.read_csv('extras/cat_map.csv')
#if contains covid remove 
kw_map = kw_map.set_index('category')
kw_map.columns.str.match("Unnamed")
kw_map = kw_map.loc[:,~kw_map.columns.str.match("Unnamed")]
print(kw_map)
kw_dict = kw_map.to_dict()
